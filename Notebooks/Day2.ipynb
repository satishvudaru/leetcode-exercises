# %%
#longest substring without repeating characters
def get_longestsubstring(str):

    seen = {}
    left=0
    max_len=0

    for i, c in enumerate(str):
        if c in seen and seen[char]>i:
            left =seen[char] +1
        
        seen[char]=right
        max_len =max(max_len,right-left+1)
   

s='abcabcbb'
get_longestsubstring(s)
